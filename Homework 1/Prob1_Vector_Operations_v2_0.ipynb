# %% [markdown]
# ### **Problem 1. Vector Operations**

# %%
import numpy as np
# fix  seed  for  reproducible  result. Please  do not  change  the  seed
rng = np.random.default_rng(20232033)
u = rng.random((10000 ,1))
v = rng.random((10000 ,1))
w = rng.random((10000 ,1))

# %% [markdown]
# **1.1 (1.5/5) Vector Indexing and Concatenation**

# %%
solution_1_a = u[2022]
solution_1_b = v[2022:2034]
solution_1_c = np.concatenate((v[:30], w[-100:]))

print(solution_1_a)
print()
print(solution_1_b)
print()
print(solution_1_c)
# Out:
# [0.60314211]
#
# [[0.65678602]
#  [0.62798177]
#  [0.738143  ]
#  [0.94811149]
#  [0.55179546]
#  [0.64332468]
#  [0.13413764]
#  [0.88390343]
#  [0.81123801]
#  [0.652259  ]
#  [0.79811821]
#  [0.51839792]]
#
# [[0.83113392]
#  [0.56120367]
#  [0.40714254]
#  [0.02460019]
#  [0.01336789]
#  [0.23740047]
#  [0.35597481]
#  [0.42937241]
#  [0.74210288]
#  [0.90285336]
#  [0.02607093]
#  [0.44963917]
#  [0.53498762]
#  [0.40634107]
#  [0.2630476 ]
#  [0.07118791]
#  [0.70019422]
#  [0.68242921]
#  [0.69516576]
#  [0.07349177]
#  [0.81521685]
#  [0.08946658]
#  [0.58332285]
#  [0.85940941]
#  [0.59890161]
#  [0.9019855 ]
#  [0.67572507]
#  [0.69824556]
#  [0.21278617]
#  [0.32064074]
#  [0.85395778]
#  [0.35686649]
#  [0.82820314]
#  [0.84829925]
#  [0.41450186]
#  [0.80222036]
#  [0.291635  ]
#  [0.96926886]
#  [0.13700848]
#  [0.47577132]
#  [0.28188049]
#  [0.37626924]
#  [0.92659446]
#  [0.76645543]
#  [0.06965738]
#  [0.16633979]
#  [0.86241119]
#  [0.61268771]
#  [0.42784691]
#  [0.52975043]
#  [0.50287865]
#  [0.78688485]
#  [0.42783973]
#  [0.85291338]
#  [0.2349399 ]
#  [0.51221287]
#  [0.67892029]
#  [0.84400258]
#  [0.62394493]
#  [0.21639092]
#  [0.35840179]
#  [0.71589193]
#  [0.54047449]
#  [0.69445888]
#  [0.54116681]
#  [0.95038946]
#  [0.89689123]
#  [0.72797298]
#  [0.97874459]
#  [0.31040894]
#  [0.24776553]
#  [0.21496028]
#  [0.34054181]
#  [0.72426924]
#  [0.11740829]
#  [0.8722269 ]
#  [0.7104599 ]
#  [0.45964185]
#  [0.28069009]
#  [0.79490074]
#  [0.27680276]
#  [0.97499743]
#  [0.12345431]
#  [0.03571117]
#  [0.38070807]
#  [0.51639535]
#  [0.98484165]
#  [0.04637442]
#  [0.27586562]
#  [0.75059138]
#  [0.48854502]
#  [0.95498849]
#  [0.92181265]
#  [0.87084824]
#  [0.45558987]
#  [0.646107  ]
#  [0.55264748]
#  [0.67992938]
#  [0.80712194]
#  [0.4686936 ]
#  [0.63828434]
#  [0.86640501]
#  [0.29132524]
#  [0.50730173]
#  [0.50860324]
#  [0.28844407]
#  [0.30314646]
#  [0.81240696]
#  [0.13610825]
#  [0.00185525]
#  [0.71468568]
#  [0.36203484]
#  [0.62021586]
#  [0.42588028]
#  [0.16707597]
#  [0.5287955 ]
#  [0.55022363]
#  [0.15547485]
#  [0.22544936]
#  [0.6725141 ]
#  [0.0475933 ]
#  [0.60397999]
#  [0.29619553]
#  [0.12225818]
#  [0.19030474]
#  [0.73032552]
#  [0.66172851]
#  [0.91859113]
#  [0.62820253]
#  [0.14254277]]

# %% [markdown]
# **1.2 (1/5) Linear Combination**

# %%
solution_2_a = u + v + w

solution_2_b = 2*u + 3*v + 3*w

print(solution_2_a)
print()
print(solution_2_b)
# Out:
# [[2.08485402]
#  [1.73665664]
#  [1.50197551]
#  ...
#  [2.29001003]
#  [1.9876794 ]
#  [1.64777379]]
#
# [[5.46122687]
#  [4.67762199]
#  [3.5376305 ]
#  ...
#  [6.3975946 ]
#  [5.16694204]
#  [4.42177553]]

# %% [markdown]
# **1.3 (1.5/5) Inner Product**

# %%
solution_3_a = np.inner(u.flatten(), u.flatten())

solution_3_b = np.inner((u - 2*v).flatten(), w.flatten())

solution_3_c = np.inner((3*u).flatten(), (2*v + w).flatten())

print(solution_3_a)
print()
print(solution_3_b)
print()
print(solution_3_c)
# Out:
# 3334.1385686005715
#
# -2485.1550842450188
#
# 22422.60043616603

# %% [markdown]
# **1.4 (1/5) Vector Norm**

# %%
solution_4_a = np.linalg.norm(u)

solution_4_b = np.linalg.norm(v + 3*w)

print(solution_4_a)
print()
print(solution_4_b)
# Out:
# 57.74200003983731
#
# 219.0097026340124
